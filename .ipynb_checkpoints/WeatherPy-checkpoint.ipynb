# %% [markdown]
# # WeatherPy

# %% [markdown]
# # Analysis:
#     - The temperature charts shows the relationship between the latitude and the degree of temperature
#     which is inversely related.
#     - The humidity is high as the latitude increases in its axis,it is necessary to understand vapour pressure and in particular the gaseous nature of water vapour.
#     -The latitude and Cloudness shows that vapour also affects the weather because, as indicated below, it condenses into clouds and falls as rain or other forms of precipitation.
#     - The lower the speed of wind in the higher latitude the more concentration of of water vapour inin the atmosphere.The basic relationship between atmospheric pressure and horizontal wind is revealed by disregarding friction and any changes in wind direction and speed.

# %%
# Dependencies
import random
import requests as req

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

from citipy import citipy

import openweathermapy as owm

#To get the current date
import datetime
now = datetime.datetime.now()

# %% [markdown]
# Generate Cities List:

# %%
# Create a settings object with your API key and preferred units
api_key = "2092f20a9cc5d2c19008fc62765c923e"
# Setting the units to imperial to get Fahrenheit reading
settings = {"units": "imperial", "appid": api_key}

# %% [markdown]
# Perform API Calls:

# %%
# Latitude ranges from -90 to 90 and Longitude ranges from -180 to 180
lat = list(np.arange(-90,90.01,0.01))
long = list(np.arange(-180,180.01,0.01))

# Setting Latitude and Longitude to ramdomly pick co-ordinates.
lat_samples=random.sample(lat,2500)
long_samples=random.sample(long,2500)

# Creating a dataframe from the randomly sample Latitude and Longitude
cities_df=pd.DataFrame({"Latitude":lat_samples,"Longitude":long_samples})

#Creating new columns City and Country for storing the details corresponding to the co-ordinates
cities_df["City"]=""
cities_df["Country"]=""

# Finding the city and the country code corresponding to the Latitude and Longitude
for index,row in cities_df.iterrows():
    city=citipy.nearest_city(row["Latitude"], row["Longitude"])
    cities_df.set_value(index, "City", city.city_name)
    cities_df.set_value(index, "Country", city.country_code)

# Dropping the Latitude and Longitude as they are values of the nearest city and not the excat co-ordinates of the city
cities_df=cities_df.drop(cities_df.columns[[0, 1]], axis=1)

# Deleting duplicate values from the list of cities and keeping only the first
cities_df=cities_df.drop_duplicates(['City'], keep='first')

# Randomly sampling a list of 800 cities 
cities_df=cities_df.sample(n=800)

# Resetting the index of the cities list
cities_df=cities_df.reset_index(drop=True)

cities_df.head()
# Out:
# C:\Users\mikef\Anaconda3\lib\site-packages\ipykernel_launcher.py:19: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\mikef\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#            City Country
# 0         mecca      sa
# 1     te karaka      nz
# 2     tazovskiy      ru
# 3  druskininkai      lt
# 4      krizevci      hr

# %%
# Get data for each city in cities_df
weather_data = []

url="https://api.openweathermap.org/data/2.5/weather?appid=" + api_key + "&units=imperial&q="

print("\nStats Data Minning\n-----------------------------")
#Get the response from OpenWeatherMapY and storing the response into weather_data if response is found
for index,row in cities_df.iterrows():  
    print("\nProcessing record %s|%s,%s"%((index+1),row["City"],row["Country"]))
    print("\n"+url+"%s,%s"%(row["City"].replace(" ","+"),row["Country"]))
    try:
        response = owm.get_current("%s,%s"%(row["City"],row["Country"]), **settings)
        # Appending the response to the weather_Data
        weather_data.append(response)
    except:
        print("\n\033[1;31mCity not found. Skipping...\033[1;30m")

print("\n-----------------------------\nData Minning Completed\n-----------------------------")
# Out:
# Stats Data Minning
# -----------------------------
#
# Processing record 1|mecca,sa
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=mecca,sa
#
# Processing record 2|te karaka,nz
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=te+karaka,nz
#
# Processing record 3|tazovskiy,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=tazovskiy,ru
#
# Processing record 4|druskininkai,lt
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=druskininkai,lt
#
# Processing record 5|krizevci,hr
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=krizevci,hr
#
# Processing record 6|magadan,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=magadan,ru
#
# Processing record 7|birjand,ir
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=birjand,ir
#
# Processing record 8|bell ville,ar
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=bell+ville,ar
#
# Processing record 9|narsaq,gl
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=narsaq,gl
#
# Processing record 10|arucas,es
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=arucas,es
#
# Processing record 11|klaksvik,fo
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=klaksvik,fo
#
# Processing record 12|rohatyn,ua
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=rohatyn,ua
#
# Processing record 13|fairbanks,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=fairbanks,us
#
# Processing record 14|glyadyanskoye,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=glyadyanskoye,ru
#
# Processing record 15|korla,cn
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=korla,cn
#
# Processing record 16|kharp,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=kharp,ru
#
# Processing record 17|haibowan,cn
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=haibowan,cn
#
# City not found. Skipping...
#
# Processing record 18|taolanaro,mg
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=taolanaro,mg
#
# City not found. Skipping...
#
# Processing record 19|amapa,br
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=amapa,br
#
# Processing record 20|lovozero,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=lovozero,ru
#
# Processing record 21|hearst,ca
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=hearst,ca
#
# Processing record 22|roald,no
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=roald,no
#
# Processing record 23|norman wells,ca
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=norman+wells,ca
#
# Processing record 24|charters towers,au
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=charters+towers,au
#
# Processing record 25|gao,ml
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=gao,ml
#
# Processing record 26|shieli,kz
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=shieli,kz
#
# Processing record 27|harper,lr
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=harper,lr
#
# Processing record 28|kralendijk,an
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=kralendijk,an
#
# City not found. Skipping...
#
# Processing record 29|panzhihua,cn
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=panzhihua,cn
#
# Processing record 30|xiaoweizhai,cn
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=xiaoweizhai,cn
#
# Processing record 31|west bay,ky
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=west+bay,ky
#
# Processing record 32|severo-kurilsk,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=severo-kurilsk,ru
#
# Processing record 33|tarakan,id
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=tarakan,id
#
# Processing record 34|washougal,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=washougal,us
#
# Processing record 35|jiayuguan,cn
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=jiayuguan,cn
#
# Processing record 36|dosso,ne
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=dosso,ne
#
# Processing record 37|tuktoyaktuk,ca
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=tuktoyaktuk,ca
#
# Processing record 38|barentsburg,sj
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=barentsburg,sj
#
# City not found. Skipping...
#
# Processing record 39|eirunepe,br
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=eirunepe,br
#
# Processing record 40|chulman,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=chulman,ru
#
# Processing record 41|cayenne,gf
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=cayenne,gf
#
# Processing record 42|berlevag,no
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=berlevag,no
#
# Processing record 43|mabaruma,gy
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=mabaruma,gy
#
# Processing record 44|byron bay,au
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=byron+bay,au
#
# Processing record 45|ravar,ir
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=ravar,ir
#
# Processing record 46|yeniseysk,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=yeniseysk,ru
#
# Processing record 47|romilly-sur-seine,fr
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=romilly-sur-seine,fr
#
# Processing record 48|hamilton,bm
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=hamilton,bm
#
# Processing record 49|hobyo,so
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=hobyo,so
#
# Processing record 50|otukpo,ng
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=otukpo,ng
#
# Processing record 51|tamana,jp
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=tamana,jp
#
# Processing record 52|tenenkou,ml
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=tenenkou,ml
#
# Processing record 53|smolenka,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=smolenka,ru
# Processing record 54|beyneu,kz
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=beyneu,kz
#
# Processing record 55|aiquile,bo
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=aiquile,bo
#
# Processing record 56|busselton,au
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=busselton,au
#
# Processing record 57|zhezkazgan,kz
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=zhezkazgan,kz
#
# Processing record 58|bayir,jo
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=bayir,jo
#
# City not found. Skipping...
#
# Processing record 59|gold coast,au
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=gold+coast,au
#
# Processing record 60|bantry,ie
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=bantry,ie
#
# Processing record 61|kendari,id
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=kendari,id
#
# Processing record 62|port-gentil,ga
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=port-gentil,ga
#
# Processing record 63|lahij,ye
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=lahij,ye
#
# Processing record 64|manoharpur,in
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=manoharpur,in
#
# Processing record 65|ridgecrest,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=ridgecrest,us
#
# Processing record 66|shimanovsk,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=shimanovsk,ru
#
# Processing record 67|senador jose porfirio,br
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=senador+jose+porfirio,br
#
# Processing record 68|labuan,my
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=labuan,my
#
# Processing record 69|bon accord,ca
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=bon+accord,ca
#
# Processing record 70|beringovskiy,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=beringovskiy,ru
#
# Processing record 71|ostrovnoy,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=ostrovnoy,ru
#
# Processing record 72|denpasar,id
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=denpasar,id
#
# Processing record 73|haikou,cn
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=haikou,cn
#
# Processing record 74|saint-augustin,ca
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=saint-augustin,ca
#
# Processing record 75|namatanai,pg
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=namatanai,pg
#
# Processing record 76|latung,ph
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=latung,ph
#
# Processing record 77|labrea,br
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=labrea,br
#
# Processing record 78|warri,ng
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=warri,ng
#
# Processing record 79|alice springs,au
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=alice+springs,au
#
# Processing record 80|balotra,in
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=balotra,in
#
# Processing record 81|frontera,mx
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=frontera,mx
#
# Processing record 82|baijiantan,cn
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=baijiantan,cn
#
# Processing record 83|georgetown,sh
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=georgetown,sh
#
# Processing record 84|baiyin,cn
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=baiyin,cn
#
# Processing record 85|doha,kw
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=doha,kw
#
# City not found. Skipping...
#
# Processing record 86|banda aceh,id
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=banda+aceh,id
#
# Processing record 87|vila franca do campo,pt
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=vila+franca+do+campo,pt
#
# Processing record 88|caravelas,br
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=caravelas,br
#
# Processing record 89|clyde river,ca
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=clyde+river,ca
#
# Processing record 90|lompoc,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=lompoc,us
#
# Processing record 91|fort dodge,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=fort+dodge,us
#
# Processing record 92|ponta do sol,pt
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=ponta+do+sol,pt
#
# Processing record 93|coquimbo,cl
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=coquimbo,cl
#
# Processing record 94|wattegama,lk
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=wattegama,lk
#
# Processing record 95|rocha,uy
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=rocha,uy
#
# Processing record 96|nome,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=nome,us
#
# Processing record 97|chapais,ca
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=chapais,ca
#
# Processing record 98|umzimvubu,za
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=umzimvubu,za
#
# City not found. Skipping...
#
# Processing record 99|chuy,uy
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=chuy,uy
#
# Processing record 100|gigmoto,ph
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=gigmoto,ph
#
# Processing record 101|bitung,id
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=bitung,id
#
# Processing record 102|nhulunbuy,au
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=nhulunbuy,au
#
# Processing record 103|bandar-e lengeh,ir
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=bandar-e+lengeh,ir
#
# Processing record 104|pangai,to
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=pangai,to
#
# Processing record 105|elverum,no
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=elverum,no
#
# Processing record 106|ginir,et
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=ginir,et
#
# Processing record 107|chara,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=chara,ru
# Processing record 108|beziers,fr
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=beziers,fr
#
# Processing record 109|eureka,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=eureka,us
#
# Processing record 110|yeppoon,au
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=yeppoon,au
#
# Processing record 111|nabire,id
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=nabire,id
#
# Processing record 112|borogontsy,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=borogontsy,ru
#
# Processing record 113|alofi,nu
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=alofi,nu
#
# Processing record 114|luba,gq
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=luba,gq
#
# Processing record 115|graham,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=graham,us
#
# Processing record 116|makubetsu,jp
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=makubetsu,jp
#
# Processing record 117|port lincoln,au
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=port+lincoln,au
#
# Processing record 118|avera,pf
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=avera,pf
#
# City not found. Skipping...
#
# Processing record 119|vardo,no
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=vardo,no
#
# Processing record 120|labytnangi,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=labytnangi,ru
#
# Processing record 121|ajdabiya,ly
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=ajdabiya,ly
#
# Processing record 122|tucuman,ar
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=tucuman,ar
#
# Processing record 123|storforshei,no
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=storforshei,no
#
# Processing record 124|padang,id
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=padang,id
#
# Processing record 125|pudozh,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=pudozh,ru
#
# Processing record 126|bardiyah,ly
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=bardiyah,ly
#
# Processing record 127|klenovyy,ua
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=klenovyy,ua
#
# Processing record 128|kavaratti,in
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=kavaratti,in
#
# Processing record 129|camapua,br
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=camapua,br
#
# Processing record 130|akyab,mm
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=akyab,mm
#
# Processing record 131|hualmay,pe
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=hualmay,pe
#
# Processing record 132|ellensburg,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=ellensburg,us
#
# Processing record 133|iqaluit,ca
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=iqaluit,ca
#
# Processing record 134|san luis,mx
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=san+luis,mx
#
# Processing record 135|constitucion,mx
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=constitucion,mx
#
# Processing record 136|dolinsk,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=dolinsk,ru
#
# Processing record 137|lata,sb
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=lata,sb
#
# City not found. Skipping...
#
# Processing record 138|penzance,gb
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=penzance,gb
#
# Processing record 139|port jervis,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=port+jervis,us
#
# Processing record 140|sorvag,fo
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=sorvag,fo
#
# City not found. Skipping...
#
# Processing record 141|smithers,ca
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=smithers,ca
#
# Processing record 142|sigayevo,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=sigayevo,ru
#
# Processing record 143|mulchen,cl
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=mulchen,cl
#
# Processing record 144|mishelevka,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=mishelevka,ru
#
# Processing record 145|grand river south east,mu
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=grand+river+south+east,mu
#
# City not found. Skipping...
#
# Processing record 146|ayagoz,kz
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=ayagoz,kz
#
# Processing record 147|bandarbeyla,so
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=bandarbeyla,so
#
# Processing record 148|mataura,pf
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=mataura,pf
#
# City not found. Skipping...
#
# Processing record 149|barawe,so
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=barawe,so
#
# City not found. Skipping...
#
# Processing record 150|victoria,sc
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=victoria,sc
#
# Processing record 151|syamzha,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=syamzha,ru
#
# Processing record 152|inirida,co
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=inirida,co
#
# Processing record 153|kabalo,cd
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=kabalo,cd
#
# Processing record 154|baykit,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=baykit,ru
#
# Processing record 155|port hedland,au
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=port+hedland,au
#
# Processing record 156|novo aripuana,br
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=novo+aripuana,br
#
# Processing record 157|verkhnevilyuysk,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=verkhnevilyuysk,ru
#
# Processing record 158|fevralsk,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=fevralsk,ru
#
# City not found. Skipping...
#
# Processing record 159|carnarvon,au
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=carnarvon,au
#
# Processing record 160|ossora,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=ossora,ru
#
# Processing record 161|geraldton,au
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=geraldton,au
# Processing record 162|lalmohan,bd
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=lalmohan,bd
#
# Processing record 163|xuddur,so
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=xuddur,so
#
# Processing record 164|yialos,gr
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=yialos,gr
#
# City not found. Skipping...
#
# Processing record 165|blagoyevo,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=blagoyevo,ru
#
# Processing record 166|dingle,ie
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=dingle,ie
#
# Processing record 167|tigil,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=tigil,ru
#
# Processing record 168|hasaki,jp
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=hasaki,jp
#
# Processing record 169|san cristobal,ec
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=san+cristobal,ec
#
# Processing record 170|rio gallegos,ar
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=rio+gallegos,ar
#
# Processing record 171|pingdingshan,cn
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=pingdingshan,cn
#
# Processing record 172|swan river,ca
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=swan+river,ca
#
# Processing record 173|los llanos de aridane,es
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=los+llanos+de+aridane,es
#
# Processing record 174|takoradi,gh
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=takoradi,gh
#
# Processing record 175|lolua,tv
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=lolua,tv
#
# City not found. Skipping...
#
# Processing record 176|raga,sd
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=raga,sd
#
# City not found. Skipping...
#
# Processing record 177|kudahuvadhoo,mv
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=kudahuvadhoo,mv
#
# Processing record 178|samusu,ws
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=samusu,ws
#
# City not found. Skipping...
#
# Processing record 179|oinoussai,gr
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=oinoussai,gr
#
# City not found. Skipping...
#
# Processing record 180|panalingaan,ph
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=panalingaan,ph
#
# Processing record 181|ixtapa,mx
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=ixtapa,mx
#
# Processing record 182|karasjok,no
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=karasjok,no
#
# Processing record 183|maningrida,au
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=maningrida,au
#
# Processing record 184|trairi,br
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=trairi,br
#
# Processing record 185|chardara,kz
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=chardara,kz
#
# Processing record 186|houlton,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=houlton,us
#
# Processing record 187|broome,au
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=broome,au
#
# Processing record 188|rumphi,mw
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=rumphi,mw
#
# Processing record 189|presidencia roque saenz pena,ar
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=presidencia+roque+saenz+pena,ar
#
# Processing record 190|talnakh,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=talnakh,ru
#
# Processing record 191|codrington,ag
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=codrington,ag
#
# City not found. Skipping...
#
# Processing record 192|moen,no
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=moen,no
#
# Processing record 193|salalah,om
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=salalah,om
#
# Processing record 194|winslow,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=winslow,us
#
# Processing record 195|bocas del toro,pa
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=bocas+del+toro,pa
#
# Processing record 196|leeton,au
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=leeton,au
#
# Processing record 197|sibolga,id
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=sibolga,id
#
# Processing record 198|natal,br
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=natal,br
#
# Processing record 199|comodoro rivadavia,ar
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=comodoro+rivadavia,ar
#
# Processing record 200|diebougou,bf
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=diebougou,bf
#
# Processing record 201|magistralnyy,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=magistralnyy,ru
#
# Processing record 202|mufumbwe,zm
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=mufumbwe,zm
#
# Processing record 203|pandamatenga,bw
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=pandamatenga,bw
#
# Processing record 204|kursenai,lt
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=kursenai,lt
#
# Processing record 205|falealupo,ws
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=falealupo,ws
#
# City not found. Skipping...
#
# Processing record 206|sawtell,au
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=sawtell,au
#
# Processing record 207|tessalit,ml
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=tessalit,ml
#
# Processing record 208|naze,jp
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=naze,jp
#
# Processing record 209|nang rong,th
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=nang+rong,th
#
# Processing record 210|kwinana,au
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=kwinana,au
#
# Processing record 211|lebu,cl
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=lebu,cl
#
# Processing record 212|porto walter,br
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=porto+walter,br
#
# Processing record 213|sestri levante,it
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=sestri+levante,it
# Processing record 214|saskylakh,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=saskylakh,ru
#
# Processing record 215|dolores,ar
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=dolores,ar
#
# Processing record 216|cortez,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=cortez,us
#
# Processing record 217|fare,pf
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=fare,pf
#
# Processing record 218|guaruja,br
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=guaruja,br
#
# Processing record 219|roros,no
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=roros,no
#
# Processing record 220|iguape,br
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=iguape,br
#
# Processing record 221|jiaozuo,cn
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=jiaozuo,cn
#
# Processing record 222|ribeira grande,pt
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=ribeira+grande,pt
#
# Processing record 223|adet,et
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=adet,et
#
# Processing record 224|palabuhanratu,id
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=palabuhanratu,id
#
# City not found. Skipping...
#
# Processing record 225|stephenville,ca
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=stephenville,ca
#
# Processing record 226|angoche,mz
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=angoche,mz
#
# Processing record 227|bonthe,sl
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=bonthe,sl
#
# Processing record 228|halalo,wf
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=halalo,wf
#
# City not found. Skipping...
#
# Processing record 229|ilulissat,gl
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=ilulissat,gl
#
# Processing record 230|rivadavia,ar
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=rivadavia,ar
#
# Processing record 231|maple creek,ca
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=maple+creek,ca
#
# Processing record 232|san rafael,ar
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=san+rafael,ar
#
# Processing record 233|niteroi,br
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=niteroi,br
#
# Processing record 234|coxim,br
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=coxim,br
#
# Processing record 235|puerto ayora,ec
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=puerto+ayora,ec
#
# Processing record 236|kalabo,zm
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=kalabo,zm
#
# Processing record 237|puntarenas,cr
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=puntarenas,cr
#
# Processing record 238|atherton,au
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=atherton,au
#
# Processing record 239|hirara,jp
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=hirara,jp
#
# Processing record 240|carbondale,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=carbondale,us
#
# Processing record 241|thompson,ca
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=thompson,ca
#
# Processing record 242|makakilo city,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=makakilo+city,us
#
# Processing record 243|fort nelson,ca
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=fort+nelson,ca
#
# Processing record 244|chokurdakh,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=chokurdakh,ru
#
# Processing record 245|guiratinga,br
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=guiratinga,br
#
# Processing record 246|okhotsk,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=okhotsk,ru
#
# Processing record 247|evensk,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=evensk,ru
#
# Processing record 248|dera bugti,pk
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=dera+bugti,pk
#
# Processing record 249|boa vista,br
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=boa+vista,br
#
# Processing record 250|attawapiskat,ca
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=attawapiskat,ca
#
# City not found. Skipping...
#
# Processing record 251|poum,nc
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=poum,nc
#
# Processing record 252|jiuquan,cn
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=jiuquan,cn
#
# Processing record 253|zaraza,ve
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=zaraza,ve
#
# Processing record 254|wuxue,cn
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=wuxue,cn
#
# Processing record 255|mount isa,au
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=mount+isa,au
#
# Processing record 256|tura,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=tura,ru
#
# Processing record 257|saryshagan,kz
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=saryshagan,kz
#
# City not found. Skipping...
#
# Processing record 258|nguiu,au
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=nguiu,au
#
# City not found. Skipping...
#
# Processing record 259|shirokiy,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=shirokiy,ru
#
# Processing record 260|svetlaya,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=svetlaya,ru
#
# Processing record 261|katsuura,jp
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=katsuura,jp
#
# Processing record 262|yumen,cn
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=yumen,cn
#
# Processing record 263|danville,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=danville,us
#
# Processing record 264|winnemucca,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=winnemucca,us
#
# Processing record 265|montague,ca
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=montague,ca
#
# Processing record 266|hofn,is
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=hofn,is
#
# Processing record 267|puerto baquerizo moreno,ec
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=puerto+baquerizo+moreno,ec
# Processing record 268|novyy urgal,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=novyy+urgal,ru
#
# Processing record 269|nadym,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=nadym,ru
#
# Processing record 270|lorengau,pg
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=lorengau,pg
#
# Processing record 271|vilcun,cl
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=vilcun,cl
#
# Processing record 272|kurilsk,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=kurilsk,ru
#
# Processing record 273|farafangana,mg
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=farafangana,mg
#
# Processing record 274|viligili,mv
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=viligili,mv
#
# City not found. Skipping...
#
# Processing record 275|sur,om
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=sur,om
#
# Processing record 276|souillac,mu
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=souillac,mu
#
# Processing record 277|muros,es
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=muros,es
#
# Processing record 278|touros,br
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=touros,br
#
# Processing record 279|antalaha,mg
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=antalaha,mg
#
# Processing record 280|aripuana,br
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=aripuana,br
#
# Processing record 281|abnub,eg
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=abnub,eg
#
# Processing record 282|tsihombe,mg
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=tsihombe,mg
#
# City not found. Skipping...
#
# Processing record 283|svetlogorsk,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=svetlogorsk,ru
#
# Processing record 284|harindanga,in
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=harindanga,in
#
# Processing record 285|baicheng,cn
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=baicheng,cn
#
# Processing record 286|tyazhinskiy,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=tyazhinskiy,ru
#
# Processing record 287|elko,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=elko,us
#
# Processing record 288|road town,vg
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=road+town,vg
#
# Processing record 289|coahuayana,mx
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=coahuayana,mx
#
# Processing record 290|tautira,pf
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=tautira,pf
#
# Processing record 291|obo,cf
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=obo,cf
#
# Processing record 292|taitung,tw
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=taitung,tw
#
# Processing record 293|turbat,pk
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=turbat,pk
#
# Processing record 294|khatanga,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=khatanga,ru
#
# Processing record 295|provideniya,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=provideniya,ru
#
# Processing record 296|margate,za
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=margate,za
#
# Processing record 297|kilindoni,tz
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=kilindoni,tz
#
# Processing record 298|punta arenas,cl
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=punta+arenas,cl
#
# Processing record 299|glendive,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=glendive,us
#
# Processing record 300|excelsior springs,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=excelsior+springs,us
#
# Processing record 301|yuxia,cn
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=yuxia,cn
#
# Processing record 302|pacific grove,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=pacific+grove,us
#
# Processing record 303|fort oglethorpe,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=fort+oglethorpe,us
#
# Processing record 304|victor harbor,au
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=victor+harbor,au
#
# Processing record 305|qaqortoq,gl
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=qaqortoq,gl
#
# Processing record 306|poronaysk,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=poronaysk,ru
#
# Processing record 307|taoudenni,ml
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=taoudenni,ml
#
# Processing record 308|kyshtovka,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=kyshtovka,ru
#
# Processing record 309|karauzyak,uz
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=karauzyak,uz
#
# City not found. Skipping...
#
# ...
#
# Processing record 699|gizo,sb
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=gizo,sb
#
# Processing record 700|haines junction,ca
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=haines+junction,ca
#
# Processing record 701|shibarghan,af
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=shibarghan,af
#
# City not found. Skipping...
#
# Processing record 702|oranjemund,na
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=oranjemund,na
#
# Processing record 703|nagato,jp
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=nagato,jp
#
# Processing record 704|port alfred,za
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=port+alfred,za
#
# Processing record 705|hoi an,vn
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=hoi+an,vn
# Processing record 706|pevek,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=pevek,ru
#
# Processing record 707|sol-iletsk,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=sol-iletsk,ru
#
# Processing record 708|sebring,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=sebring,us
#
# Processing record 709|hihifo,to
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=hihifo,to
#
# City not found. Skipping...
#
# Processing record 710|rudbar,af
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=rudbar,af
#
# Processing record 711|cravo norte,co
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=cravo+norte,co
#
# Processing record 712|sekoma,bw
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=sekoma,bw
#
# Processing record 713|namibe,ao
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=namibe,ao
#
# Processing record 714|burnie,au
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=burnie,au
#
# Processing record 715|wulanhaote,cn
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=wulanhaote,cn
#
# City not found. Skipping...
#
# Processing record 716|petropavlovsk-kamchatskiy,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=petropavlovsk-kamchatskiy,ru
#
# Processing record 717|gadung,ph
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=gadung,ph
#
# Processing record 718|port elizabeth,za
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=port+elizabeth,za
#
# Processing record 719|karaul,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=karaul,ru
#
# City not found. Skipping...
#
# Processing record 720|chimore,bo
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=chimore,bo
#
# Processing record 721|dikson,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=dikson,ru
#
# Processing record 722|basco,ph
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=basco,ph
#
# Processing record 723|fukue,jp
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=fukue,jp
#
# Processing record 724|kaoma,zm
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=kaoma,zm
#
# Processing record 725|ola,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=ola,ru
#
# Processing record 726|bhimunipatnam,in
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=bhimunipatnam,in
#
# Processing record 727|atuona,pf
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=atuona,pf
#
# Processing record 728|cabrero,cl
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=cabrero,cl
#
# Processing record 729|bambanglipuro,id
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=bambanglipuro,id
#
# Processing record 730|sitka,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=sitka,us
#
# Processing record 731|putina,pe
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=putina,pe
#
# Processing record 732|naron,es
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=naron,es
#
# Processing record 733|lieksa,fi
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=lieksa,fi
#
# Processing record 734|hohhot,cn
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=hohhot,cn
#
# Processing record 735|mineiros,br
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=mineiros,br
#
# Processing record 736|lishui,cn
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=lishui,cn
#
# Processing record 737|buala,sb
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=buala,sb
#
# Processing record 738|bredasdorp,za
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=bredasdorp,za
#
# Processing record 739|otradnoye,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=otradnoye,ru
#
# Processing record 740|kunming,cn
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=kunming,cn
#
# Processing record 741|high level,ca
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=high+level,ca
#
# Processing record 742|meadow lake,ca
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=meadow+lake,ca
#
# Processing record 743|we,nc
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=we,nc
#
# Processing record 744|ancud,cl
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=ancud,cl
#
# Processing record 745|palembang,id
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=palembang,id
#
# Processing record 746|tangi,pk
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=tangi,pk
#
# Processing record 747|abu samrah,qa
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=abu+samrah,qa
#
# City not found. Skipping...
#
# Processing record 748|sao joao da barra,br
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=sao+joao+da+barra,br
#
# Processing record 749|babushkin,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=babushkin,ru
#
# Processing record 750|killybegs,ie
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=killybegs,ie
#
# Processing record 751|turukhansk,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=turukhansk,ru
#
# Processing record 752|buarcos,pt
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=buarcos,pt
#
# Processing record 753|lulea,se
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=lulea,se
#
# Processing record 754|acarau,br
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=acarau,br
#
# Processing record 755|itoman,jp
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=itoman,jp
#
# Processing record 756|saint-pierre,pm
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=saint-pierre,pm
#
# Processing record 757|pringsewu,id
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=pringsewu,id
#
# Processing record 758|richards bay,za
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=richards+bay,za
#
# Processing record 759|andenes,no
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=andenes,no
# Processing record 760|buin,pg
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=buin,pg
#
# City not found. Skipping...
#
# Processing record 761|boende,cd
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=boende,cd
#
# Processing record 762|hastings,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=hastings,us
#
# Processing record 763|khandyga,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=khandyga,ru
#
# Processing record 764|hailar,cn
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=hailar,cn
#
# Processing record 765|goderich,sl
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=goderich,sl
#
# City not found. Skipping...
#
# Processing record 766|bluff,nz
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=bluff,nz
#
# Processing record 767|saint-philippe,re
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=saint-philippe,re
#
# Processing record 768|pisco,pe
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=pisco,pe
#
# Processing record 769|fortuna,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=fortuna,us
#
# Processing record 770|san patricio,mx
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=san+patricio,mx
#
# Processing record 771|azangaro,pe
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=azangaro,pe
#
# Processing record 772|dingzhou,cn
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=dingzhou,cn
#
# Processing record 773|damghan,ir
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=damghan,ir
#
# Processing record 774|lavrentiya,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=lavrentiya,ru
#
# Processing record 775|anqing,cn
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=anqing,cn
#
# Processing record 776|saint-jean-de-dieu,ca
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=saint-jean-de-dieu,ca
#
# City not found. Skipping...
#
# Processing record 777|oranjestad,aw
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=oranjestad,aw
#
# Processing record 778|buqayq,sa
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=buqayq,sa
#
# City not found. Skipping...
#
# Processing record 779|hermanus,za
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=hermanus,za
#
# Processing record 780|marcona,pe
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=marcona,pe
#
# City not found. Skipping...
#
# Processing record 781|tiksi,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=tiksi,ru
#
# Processing record 782|timra,se
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=timra,se
#
# Processing record 783|edgewater,us
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=edgewater,us
#
# Processing record 784|mundo nuevo,mx
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=mundo+nuevo,mx
#
# Processing record 785|aklavik,ca
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=aklavik,ca
#
# Processing record 786|paita,pe
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=paita,pe
#
# Processing record 787|vazante,br
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=vazante,br
#
# Processing record 788|mugur-aksy,ru
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=mugur-aksy,ru
#
# Processing record 789|mahebourg,mu
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=mahebourg,mu
#
# Processing record 790|port alberni,ca
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=port+alberni,ca
#
# Processing record 791|soke,tr
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=soke,tr
#
# City not found. Skipping...
#
# Processing record 792|blackwater,au
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=blackwater,au
#
# Processing record 793|horasan,tr
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=horasan,tr
#
# Processing record 794|manono,cd
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=manono,cd
#
# Processing record 795|samalaeulu,ws
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=samalaeulu,ws
#
# City not found. Skipping...
#
# Processing record 796|sharan,af
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=sharan,af
#
# Processing record 797|slave lake,ca
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=slave+lake,ca
#
# Processing record 798|lianzhou,cn
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=lianzhou,cn
#
# Processing record 799|ushuaia,ar
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=ushuaia,ar
#
# Processing record 800|kavieng,pg
#
# https://api.openweathermap.org/data/2.5/weather?appid=2092f20a9cc5d2c19008fc62765c923e&units=imperial&q=kavieng,pg
#
# -----------------------------
# Data Minning Completed
# -----------------------------

# %%
# Create an "extracts" object to get the various parameter required to form the weather data table
summary = ["name","sys.country","dt","coord.lat", "coord.lon","main.temp_max","main.humidity","wind.speed","clouds.all"]

# Create a Pandas DataFrame with the results
data = [response(*summary) for response in weather_data]
column_names = ["City","Country","Date","Latitude", "Longitude","Temperature","Humidity","Wind speed","Cloudliness"]
weather_data = pd.DataFrame(data, columns=column_names)

weather_data.head()
# Out:
#                    City Country        Date  Latitude  Longitude  Temperature  \
# 0  Makkah al Mukarramah      SA  1586628134     21.43      39.83        70.07
# 1             Te Karaka      NZ  1586628134    -38.47     177.87        49.98
# 2              Tazovsky      RU  1586628134     67.47      78.70        35.82
# 3          Druskininkai      LT  1586628134     54.02      23.97        45.00
# 4              Križevci      HR  1586628134     46.02      16.54        69.01
#
#    Humidity  Wind speed  Cloudliness
# 0        38        8.41           17
# 1        88        3.67            9
# 2        99       17.49          100
# 3        94        0.83            2
# 4        34        3.36           22

# %%
# Save the result to a csv file
weather_data.to_csv("Output/Weather_Data.csv")
# Count of the data in the dataframe
weather_data.count()
# Out:
# City           717
# Country        717
# Date           717
# Latitude       717
# Longitude      717
# Temperature    717
# Humidity       717
# Wind speed     717
# Cloudliness    717
# dtype: int64

# %%
# Creating a function to set the properties of the graph
def plotprops(xlabelname,ylabelname,xlimits):
    plt.xlabel(xlabelname)
    plt.ylabel(ylabelname)
    plt.xlim(xlimits)
    plt.title("%s vs %s (%s/%s/%s)"%(xlabelname,ylabelname,now.month,now.day,now.year),fontsize=14)
    plt.grid(True)

# %% [markdown]
# Latitude vs Temperature Plot

# %%
# Latitude vs Temperature(F)
plt.scatter(x=weather_data["Latitude"],y=weather_data["Temperature"],facecolors="blue",edgecolors="black")
plotprops("Latitude","Max. Temperature(°F)",[-90,90])
plt.savefig("Output/City Latitude vs Temperature.jpeg")
plt.show()

# %% [markdown]
# Latitude vs. Humidity Plot

# %%
# Latitude vs Humidity

plt.scatter(x=weather_data["Latitude"],y=weather_data["Humidity"],facecolors="blue",edgecolors="black")
plotprops("Latitude","Humidity(%)",[-90,90])
plt.savefig("Output/City Latitude vs Humidity.jpeg")
plt.show()

# %% [markdown]
# Latitude vs. Cloudiness Plot

# %%
# Latitude vs Cloudliness  

plt.scatter(x=weather_data["Latitude"],y=weather_data["Cloudliness"],facecolors="blue",edgecolors="black")
plotprops("Latitude","Cloudiness(%)",[-90,90])
plt.savefig("Output/City Latitude vs Cloudiness.jpeg")
plt.show()

# %% [markdown]
# Latitude vs Wind Speed

# %%
# Latitude vs Wind Speed  

plt.scatter(x=weather_data["Latitude"],y=weather_data["Wind speed"],facecolors="blue",edgecolors="black")
plotprops("Latitude","Wind speed(mph)",[-90,90])
plt.savefig("Output/City Latitude vs Wind speed.jpeg")
plt.show()
